# %% [markdown]
# # 🐍 Ejercicios sobre `break` y `continue` en Python
#
# En este cuaderno aprenderás a usar las sentencias `break` y `continue` dentro de bucles `for` y `while`.
#
# Recuerda:
# - `break` termina el bucle inmediatamente.
# - `continue` salta a la siguiente iteración del bucle, sin ejecutar el resto del código dentro del mismo.

# %% [markdown]
# ## 🔹 Ejercicio 1: Uso básico de `break`
#
# Escribe un programa que recorra los números del 1 al 20 y muestre por pantalla el primero que sea múltiplo de 7. Usa `break` para detener el bucle cuando lo encuentres.

# %%
# Escribe tu solución aquí
for i in range(1, 21):
    # tu código
    pass

# %% [markdown]
# ### 💡 Solución sugerida

# %%
for i in range(1, 21):
    if i % 7 == 0:
        print(f"El primer múltiplo de 7 es: {i}")
        break

# %% [markdown]
# ## 🔹 Ejercicio 2: Uso básico de `continue`
#
# Muestra todos los números del 1 al 10 excepto el 5. Usa `continue` para saltarlo.

# %%
# Escribe tu solución aquí
for i in range(1, 11):
    # tu código
    pass

# %% [markdown]
# ### 💡 Solución sugerida

# %%
for i in range(1, 11):
    if i == 5:
        continue
    print(i)

# %% [markdown]
# ## 🔹 Ejercicio 3: Buscar una letra en una palabra
#
# Pide al usuario una palabra y una letra. Recorre la palabra con un bucle `for` y muestra la posición (índice) donde se encuentra la primera aparición de esa letra. Si la letra no aparece, muestra un mensaje indicándolo. Usa `break` para detener el bucle cuando se encuentre.
# Implementa una segunda solución haciendo uso del else tras el for, sin necesidad de usar la variable temporal encontrada

# %%
# Escribe tu solución aquí
palabra = input("Introduce una palabra: ")
letra = input("Introduce una letra: ")

# tu código
encontrada = False
# Out:
# No encontrada

# %% [markdown]
# ### 💡 Solución sugerida

# %%
palabra = input("Introduce una palabra: ")
letra = input("Introduce una letra: ")

encontrada = False

for i in range(len(palabra)):
    if palabra[i] == letra:
        print(f"La letra '{letra}' aparece por primera vez en la posición {i}.")
        encontrada = True
        break

if not encontrada:
    print(f"La letra '{letra}' no se encuentra en la palabra '{palabra}'.")

# %%
# ------------------ VERSIÓN 2 ----------------
palabra = input("Introduce una palabra: ")
letra = input("Introduce una letra: ")

for i in range(len(palabra)):
    if palabra[i] == letra:
        print(f"La letra '{letra}' aparece por primera vez en la posición {i}.")
        break
else:
    print(f"La letra '{letra}' no se encuentra en la palabra '{palabra}'.")
# Out:
# La letra 'a' aparece por primera vez en la posición 3.

# %% [markdown]
# ## 🔹 Ejercicio 4: Uso combinado de `break` y `continue`
#
# Recorre los números del 1 al 15:
# - Si el número es múltiplo de 3, **sáltalo** usando `continue`.
# - Si el número es 12, **detén** el bucle usando `break`.
# - En los demás casos, **muestra el número** por pantalla.

# %%
# Escribe tu solución aquí
for i in range(1, 16):
    # tu código
    pass

# %% [markdown]
# ### 💡 Solución sugerida

# %%
for i in range(1, 16):
    if i % 3 == 0:
        continue
    if i == 12:
        break
    print(i)
