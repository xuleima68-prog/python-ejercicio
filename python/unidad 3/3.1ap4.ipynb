# %% [markdown]
# ### 4. Usar return
# La instrucción `return` finaliza la ejecución de la función y permite devolver un valor para que pueda ser usado posteriormente en otras partes del programa.
#
# Ejemplo de función que devuelve el cuadrado de un número:

# %%
def square_value(num):
    return num ** 2

print(square_value(2))  # 4

# %% [markdown]
# #### Ejemplo adicional
# Función que devuelve el menor y mayor de dos números:

# %%
def min_max(a, b):
    if a < b:
        return a, b
    else:
        return b, a

menor, mayor = min_max(10, 3)
print("Menor:", menor, "Mayor:", mayor)  # Menor: 3 Mayor: 10

# %% [markdown]
# ### Ejercicios adicionales

# %% [markdown]
# #### Ejercicio 4.1: Contar vocales
# Crea una función `contar_vocales(palabra)` que devuelva la cantidad de vocales en `palabra`.

# %%
def contar_vocales(palabra):
    con = 0
    for letra in palabra:
        if letra.lower() in "aeiou":
            con += 1
    return con

# %%
# Test ejercicio 4.1
assert contar_vocales('hola') == 2
assert contar_vocales('xyz') == 0
assert contar_vocales('AEIOU') == 5

# %% [markdown]
# #### Ejercicio 4.2: Suma hasta n
# Crea una función `suma_hasta(n)` que devuelva la suma de todos los números desde 1 hasta `n`.

# %%
def suma_hasta(n):
    con=0
    for i in range(1, n+1):
        con += i
    return con

# %%
# Test ejercicio 4.2
assert suma_hasta(5) == 15
assert suma_hasta(1) == 1
assert suma_hasta(10) == 55

# %% [markdown]
# #### Ejercicio 4.3: Contar caracteres específicos
# Crea una función `contar_letra(palabra, letra)` que devuelva cuántas veces aparece `letra` en `palabra`.

# %%
def contar_letra(palabra, letra):
    con = 0
    for char in palabra:
        if char == letra:
            con += 1
    return con

# %%
# Test ejercicio 4.3
assert contar_letra('banana', 'a') == 3
assert contar_letra('banana', 'b') == 1
assert contar_letra('banana', 'x') == 0
